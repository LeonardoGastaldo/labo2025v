# %% [markdown]
# <a href="https://colab.research.google.com/github/LeonardoGastaldo/labo2025v/blob/main/src/workflows/610_WorkFlow_16H_877411_63109_gerencial_julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 6 WorkFlow  Gerencial, futuro=JULIO

# %% [markdown]
# ### 6.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 6.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="gerencial_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

# %% [markdown]
# ## 6.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Wed Nov 19 12:43:12 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660436 35.3 1454497    77.7 1364003  72.9
# Vcells 1226651  9.4 8388608    64.0 1975136  15.1

# %%
principio <- Sys.time()

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 877411 #101581, 153817, 248887, 683377, 877411

PARAM$experimento <- 63109
PARAM$dataset <- "gerencial_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 6.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 6.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 6.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 6.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 6.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"           "foto_mes"
#  [3] "internet"                    "cliente_edad"
#  [5] "cliente_antiguedad"          "mrentabilidad"
#  [7] "mrentabilidad_annual"        "mcomisiones"
#  [9] "mactivos_margen"             "mpasivos_margen"
# [11] "cproductos"                  "mcuenta_corriente"
# [13] "mcaja_ahorro"                "cdescubierto_preacordado"
# [15] "mcuentas_saldo"              "ctarjeta_visa_transacciones"
# [17] "mtarjeta_visa_consumo"       "mtarjeta_master_consumo"
# [19] "mprestamos_personales"       "cpayroll_trx"
# [21] "mpayroll"                    "ccomisiones_mantenimiento"
# [23] "ccallcenter_transacciones"   "chomebanking_transacciones"
# [25] "ctrx_quarter"                "Master_status"
# [27] "Master_fechaalta"            "Master_mpagominimo"
# [29] "Visa_status"                 "Visa_fechaalta"
# [31] "Visa_mpagominimo"            "clase_ternaria"
# [33] "kmes"                        "mpayroll_sobre_edad"

# %% [markdown]
# #### 6.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 6.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 158
#   [1] "numero_de_cliente"                  "foto_mes"
#   [3] "internet"                           "cliente_edad"
#   [5] "cliente_antiguedad"                 "mrentabilidad"
#   [7] "mrentabilidad_annual"               "mcomisiones"
#   [9] "mactivos_margen"                    "mpasivos_margen"
#  [11] "cproductos"                         "mcuenta_corriente"
#  [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
#  [15] "mcuentas_saldo"                     "ctarjeta_visa_transacciones"
#  [17] "mtarjeta_visa_consumo"              "mtarjeta_master_consumo"
#  [19] "mprestamos_personales"              "cpayroll_trx"
#  [21] "mpayroll"                           "ccomisiones_mantenimiento"
#  [23] "ccallcenter_transacciones"          "chomebanking_transacciones"
#  [25] "ctrx_quarter"                       "Master_status"
#  [27] "Master_fechaalta"                   "Master_mpagominimo"
#  [29] "Visa_status"                        "Visa_fechaalta"
#  [31] "Visa_mpagominimo"                   "clase_ternaria"
#  [33] "kmes"                               "mpayroll_sobre_edad"
#  [35] "internet_lag1"                      "cliente_edad_lag1"
#  [37] "cliente_antiguedad_lag1"            "mrentabilidad_lag1"
#  [39] "mrentabilidad_annual_lag1"          "mcomisiones_lag1"
#  [41] "mactivos_margen_lag1"               "mpasivos_margen_lag1"
#  [43] "cproductos_lag1"                    "mcuenta_corriente_lag1"
#  [45] "mcaja_ahorro_lag1"                  "cdescubierto_preacordado_lag1"
#  [47] "mcuentas_saldo_lag1"                "ctarjeta_visa_transacciones_lag1"
#  [49] "mtarjeta_visa_consumo_lag1"         "mtarjeta_master_consumo_lag1"
#  [51] "mprestamos_personales_lag1"         "cpayroll_trx_lag1"
#  [53] "mpayroll_lag1"                      "ccomisiones_mantenimiento_lag1"
#  [55] "ccallcenter_transacciones_lag1"     "chomebanking_transacciones_lag1"
#  [57] "ctrx_quarter_lag1"                  "Master_status_lag1"
#  [59] "Master_fechaalta_lag1"              "Master_mpagominimo_lag1"
#  [61] "Visa_status_lag1"                   "Visa_fechaalta_lag1"
#  [63] "Visa_mpagominimo_lag1"              "kmes_lag1"
#  [65] "mpayroll_sobre_edad_lag1"           "internet_lag2"
#  [67] "cliente_edad_lag2"                  "cliente_antiguedad_lag2"
#  [69] "mrentabilidad_lag2"                 "mrentabilidad_annual_lag2"
#  [71] "mcomisiones_lag2"                   "mactivos_margen_lag2"
#  [73] "mpasivos_margen_lag2"               "cproductos_lag2"
#  [75] "mcuenta_corriente_lag2"             "mcaja_ahorro_lag2"
#  [77] "cdescubierto_preacordado_lag2"      "mcuentas_saldo_lag2"
#  [79] "ctarjeta_visa_transacciones_lag2"   "mtarjeta_visa_consumo_lag2"
#  [81] "mtarjeta_master_consumo_lag2"       "mprestamos_personales_lag2"
#  [83] "cpayroll_trx_lag2"                  "mpayroll_lag2"
#  [85] "ccomisiones_mantenimiento_lag2"     "ccallcenter_transacciones_lag2"
#  [87] "chomebanking_transacciones_lag2"    "ctrx_quarter_lag2"
#  [89] "Master_status_lag2"                 "Master_fechaalta_lag2"
#  [91] "Master_mpagominimo_lag2"            "Visa_status_lag2"
#  [93] "Visa_fechaalta_lag2"                "Visa_mpagominimo_lag2"
#  [95] "kmes_lag2"                          "mpayroll_sobre_edad_lag2"
#  [97] "internet_delta1"                    "internet_delta2"
#  [99] "cliente_edad_delta1"                "cliente_edad_delta2"
# [101] "cliente_antiguedad_delta1"          "cliente_antiguedad_delta2"
# [103] "mrentabilidad_delta1"               "mrentabilidad_delta2"
# [105] "mrentabilidad_annual_delta1"        "mrentabilidad_annual_delta2"
# [107] "mcomisiones_delta1"                 "mcomisiones_delta2"
# [109] "mactivos_margen_delta1"             "mactivos_margen_delta2"
# [111] "mpasivos_margen_delta1"             "mpasivos_margen_delta2"
# [113] "cproductos_delta1"                  "cproductos_delta2"
# [115] "mcuenta_corriente_delta1"           "mcuenta_corriente_delta2"
# [117] "mcaja_ahorro_delta1"                "mcaja_ahorro_delta2"
# [119] "cdescubierto_preacordado_delta1"    "cdescubierto_preacordado_delta2"
# [121] "mcuentas_saldo_delta1"              "mcuentas_saldo_delta2"
# [123] "ctarjeta_visa_transacciones_delta1" "ctarjeta_visa_transacciones_delta2"
# [125] "mtarjeta_visa_consumo_delta1"       "mtarjeta_visa_consumo_delta2"
# [127] "mtarjeta_master_consumo_delta1"     "mtarjeta_master_consumo_delta2"
# [129] "mprestamos_personales_delta1"       "mprestamos_personales_delta2"
# [131] "cpayroll_trx_delta1"                "cpayroll_trx_delta2"
# [133] "mpayroll_delta1"                    "mpayroll_delta2"
# [135] "ccomisiones_mantenimiento_delta1"   "ccomisiones_mantenimiento_delta2"
# [137] "ccallcenter_transacciones_delta1"   "ccallcenter_transacciones_delta2"
# [139] "chomebanking_transacciones_delta1"  "chomebanking_transacciones_delta2"
# [141] "ctrx_quarter_delta1"                "ctrx_quarter_delta2"
# [143] "Master_status_delta1"               "Master_status_delta2"
# [145] "Master_fechaalta_delta1"            "Master_fechaalta_delta2"
# [147] "Master_mpagominimo_delta1"          "Master_mpagominimo_delta2"
# [149] "Visa_status_delta1"                 "Visa_status_delta2"
# [151] "Visa_fechaalta_delta1"              "Visa_fechaalta_delta2"
# [153] "Visa_mpagominimo_delta1"            "Visa_mpagominimo_delta2"
# [155] "kmes_delta1"                        "kmes_delta2"
# [157] "mpayroll_sobre_edad_delta1"         "mpayroll_sobre_edad_delta2"

# %% [markdown]
# #### 6.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 6.3.2 Modelado

# %% [markdown]
# #### 6.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202107  obviamente completo
#
# * final_train =  [ 202005, 202105 ]  SIN undersampling
#
# * training
#    * testing = NO HAY
#    * validation =  202105   completo, sin undersampling
#    * training = [ 202005, 202104 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202105)

PARAM$trainingstrategy$training <- c(
  202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 16469

# %% [markdown]
# ####  6.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘XML’, ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_interations <- 120

# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  max_bin= 31,
  seed= PARAM$semilla_primigenia
  # learning_rate= 0.03,
  # feature_fraction= 0.5,
  # num_iterations= 2048,  # valor grande, lo limita early_stopping_rounds
  # early_stopping_rounds= 200
)


PARAM$hipeparametertuning$hs <- makeParamSet(
  # Núcleo del modelo (estructura de árboles)
  makeIntegerParam("num_leaves", lower = 2L, upper = 8192L),
  makeIntegerParam("max_depth", lower = 3L, upper = 30L),
  makeNumericParam("min_child_weight", lower = 0.001, upper = 10.0),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 0.1),

  # Regularización
  makeNumericParam("lambda_l1", lower = 0.0, upper = 1000L),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 1000L),
  makeNumericParam("scale_pos_weight", lower = 1.0, upper = 5.0),  # útil en desequilibrio

  # Control del aprendizaje
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.1),
  makeIntegerParam("num_iterations", lower = 100L, upper = 5000L),
  makeIntegerParam("early_stopping_rounds", lower = 50L, upper = 500L),

  # Submuestreo
  makeNumericParam("feature_fraction", lower = 0.05, upper = 1L),   # columnas
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 1L),   # filas
  makeIntegerParam("bagging_freq", lower = 0L, upper = 5L),         # cada N iteraciones

  # Opcionales útiles
  makeNumericParam("max_delta_step", lower = 0.0, upper = 10.0),
  makeNumericParam("path_smooth", lower = 0.0, upper = 10.0)
)
# Total: 16 hT

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_interations  # cantidad de iteraciones inteligentes
)

# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# inicio la optimizacion bayesiana

if (!file.exists("HT.RDATA")) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue("HT.RDATA") # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Wed Nov 19 12:57:27 AM 2025 AUC 0.881961542616978
#
# Wed Nov 19 12:58:24 AM 2025 AUC 0.892558830575592
#
# Wed Nov 19 12:58:52 AM 2025 AUC 0.892670395102837
#
# Wed Nov 19 12:59:17 AM 2025 AUC 0.897052951712188
#
# Wed Nov 19 12:59:32 AM 2025 AUC 0.882887612076214
#
# Wed Nov 19 01:00:05 AM 2025 AUC 0.885421552857428
#
# Wed Nov 19 01:00:52 AM 2025 AUC 0.876976705326711
#
# Wed Nov 19 01:02:03 AM 2025 AUC 0.913574567716816
#
# Wed Nov 19 01:02:50 AM 2025 AUC 0.874945559866029
#
# Wed Nov 19 01:03:09 AM 2025 AUC 0.873707780795333
#
# Wed Nov 19 01:03:42 AM 2025 AUC 0.901452788240797
#
# Wed Nov 19 01:04:19 AM 2025 AUC 0.89144519849762
#
# Wed Nov 19 01:04:54 AM 2025 AUC 0.882032172189866
#
# Wed Nov 19 01:05:47 AM 2025 AUC 0.88784745220173
#
# Wed Nov 19 01:06:13 AM 2025 AUC 0.897305272086589
#
# Wed Nov 19 01:11:10 AM 2025 AUC 0.909559922398064
#
# Wed Nov 19 01:14:50 AM 2025 AUC 0.907416205812898
#
# Wed Nov 19 01:16:40 AM 2025 AUC 0.913996331959664
#
# Wed Nov 19 01:16:56 AM 2025 AUC 0.884812897060669
#
# Wed Nov 19 01:17:43 AM 2025 AUC 0.892874734342212
#
# Wed Nov 19 01:19:15 AM 2025 AUC 0.913898692027549
#
# Wed Nov 19 01:20:20 AM 2025 AUC 0.912854850691432
#
# Wed Nov 19 01:21:19 AM 2025 AUC 0.8888953199268
#
# Wed Nov 19 01:21:39 AM 2025 AUC 0.890742761391493
#
# Wed Nov 19 01:21:52 AM 2025 AUC 0.895306841036151
#
# Wed Nov 19 01:22:20 AM 2025 AUC 0.901421751492616
#
# Wed Nov 19 01:22:30 AM 2025 AUC 0.878696980006966
#
# Wed Nov 19 01:22:45 AM 2025 AUC 0.892108210545247
#
# Wed Nov 19 01:23:14 AM 2025 AUC 0.890849796231166
#
# Wed Nov 19 01:23:41 AM 2025 AUC 0.900778871389755
#
# Wed Nov 19 01:25:27 AM 2025 AUC 0.881913897014366
#
# Wed Nov 19 01:25:41 AM 2025 AUC 0.885097596312901
#
# Wed Nov 19 01:26:43 AM 2025 AUC 0.891771000470416
#
# Wed Nov 19 01:27:02 AM 2025 AUC 0.854979871410558
#
# Wed Nov 19 01:29:03 AM 2025 AUC 0.910658119985049
#
# Wed Nov 19 01:29:45 AM 2025 AUC 0.901137555539003
#
# Wed Nov 19 01:30:37 AM 2025 AUC 0.877880126348085
#
# Wed Nov 19 01:33:44 AM 2025 AUC 0.891555924193833
#
# Wed Nov 19 01:34:41 AM 2025 AUC 0.882931734588493
#
# Wed Nov 19 01:35:09 AM 2025 AUC 0.884549336350441
#
# Wed Nov 19 01:35:29 AM 2025 AUC 0.860368018660971
#
# Wed Nov 19 01:37:06 AM 2025 AUC 0.89813135288682
#
# Wed Nov 19 01:37:41 AM 2025 AUC 0.911433870923365
#
# Wed Nov 19 01:38:19 AM 2025 AUC 0.814387663412673
#
# Wed Nov 19 01:38:54 AM 2025 AUC 0.891845656432257
#
# Wed Nov 19 01:39:50 AM 2025 AUC 0.902119155612551
#
# Wed Nov 19 01:44:30 AM 2025 AUC 0.886914504328033
#
# Wed Nov 19 01:53:51 AM 2025 AUC 0.92028790023145
#
# Wed Nov 19 01:54:36 AM 2025 AUC 0.888939274672873
#
# Wed Nov 19 01:54:48 AM 2025 AUC 0.880497614700078
#
# Wed Nov 19 01:55:47 AM 2025 AUC 0.904221266178534
#
# Wed Nov 19 01:58:33 AM 2025 AUC 0.900152767907533
#
# Wed Nov 19 01:59:10 AM 2025 AUC 0.872841771637982
#
# Wed Nov 19 01:59:41 AM 2025 AUC 0.898989812564884
#
# Wed Nov 19 02:00:37 AM 2025 AUC 0.893920588872806
#
# Wed Nov 19 02:00:52 AM 2025 AUC 0.885480942094487
#
# Wed Nov 19 02:01:23 AM 2025 AUC 0.892532826813603
#
# Wed Nov 19 02:04:40 AM 2025 AUC 0.919737627074513
#
# Wed Nov 19 02:05:52 AM 2025 AUC 0.899826965934736
#
# Wed Nov 19 02:06:07 AM 2025 AUC 0.888754228547232
#
# Wed Nov 19 02:06:14 AM 2025 AUC 0.842319226879636
#
# Wed Nov 19 02:06:51 AM 2025 AUC 0.881743614314886
#
# Wed Nov 19 02:09:38 AM 2025 AUC 0.90036163683448
#
# Wed Nov 19 02:09:47 AM 2025 AUC 0.875840089278464
#
# [mbo] 0: num_leaves=5904; max_depth=24; min_child_weight=6.14; min_data_in_leaf=6184; min_gain_to_split=0.0556; lambda_l1=807; lambda_l2=387; scale_pos_weight=3.35; learning_rate=0.0291; num_iterations=1676; early_stopping_rounds=271; feature_fraction=0.625; bagging_fraction=0.575; bagging_freq=1; max_delta_step=2.57; path_smooth=3.44 : y = 0.882 : 34.4 secs : initdesign
#
# [mbo] 0: num_leaves=6647; max_depth=16; min_child_weight=8.64; min_data_in_leaf=1961; min_gain_to_split=0.0602; lambda_l1=267; lambda_l2=600; scale_pos_weight=2.49; learning_rate=0.0816; num_iterations=2654; early_stopping_rounds=323; feature_fraction=0.504; bagging_fraction=0.657; bagging_freq=3; max_delta_step=5.84; path_smooth=6.54 : y = 0.893 : 57.3 secs : initdesign
#
# [mbo] 0: num_leaves=4806; max_depth=13; min_child_weight=2.38; min_data_in_leaf=4610; min_gain_to_split=0.079; lambda_l1=433; lambda_l2=38.2; scale_pos_weight=3.05; learning_rate=0.0683; num_iterations=3466; early_stopping_rounds=200; feature_fraction=0.775; bagging_fraction=0.621; bagging_freq=5; max_delta_step=5.46; path_smooth=5.35 : y = 0.893 : 27.5 secs : initdesign
#
# [mbo] 0: num_leaves=2485; max_depth=25; min_child_weight=2.85; min_data_in_leaf=1507; min_gain_to_split=0.0504; lambda_l1=464; lambda_l2=65.8; scale_pos_weight=2.75; learning_rate=0.0642; num_iterations=2239; early_stopping_rounds=298; feature_fraction=0.638; bagging_fraction=0.848; bagging_freq=4; max_delta_step=3.9; path_smooth=9.47 : y = 0.897 : 25.4 secs : initdesign
#
# [mbo] 0: num_leaves=6752; max_depth=15; min_child_weight=8.36; min_data_in_leaf=4753; min_gain_to_split=0.0583; lambda_l1=547; lambda_l2=488; scale_pos_weight=2.94; learning_rate=0.0241; num_iterations=1531; early_stopping_rounds=118; feature_fraction=0.827; bagging_fraction=0.54; bagging_freq=1; max_delta_step=6.35; path_smooth=1.8 : y = 0.883 : 15.2 secs : initdesign
#
# [mbo] 0: num_leaves=2144; max_depth=19; min_child_weight=1.6; min_data_in_leaf=7261; min_gain_to_split=0.0388; lambda_l1=754; lambda_l2=663; scale_pos_weight=3.85; learning_rate=0.0569; num_iterations=2506; early_stopping_rounds=428; feature_fraction=0.732; bagging_fraction=0.77; bagging_freq=2; max_delta_step=6.85; path_smooth=2.03 : y = 0.885 : 33.1 secs : initdesign
#
# [mbo] 0: num_leaves=2693; max_depth=12; min_child_weight=2.56; min_data_in_leaf=6359; min_gain_to_split=0.0446; lambda_l1=508; lambda_l2=336; scale_pos_weight=1.8; learning_rate=0.0884; num_iterations=3016; early_stopping_rounds=436; feature_fraction=0.376; bagging_fraction=0.654; bagging_freq=3; max_delta_step=8.64; path_smooth=6.32 : y = 0.877 : 46.6 secs : initdesign
#
# [mbo] 0: num_leaves=4012; max_depth=12; min_child_weight=6.06; min_data_in_leaf=2698; min_gain_to_split=0.0258; lambda_l1=80.5; lambda_l2=544; scale_pos_weight=3.21; learning_rate=0.0823; num_iterations=861; early_stopping_rounds=416; feature_fraction=0.0902; bagging_fraction=0.831; bagging_freq=1; max_delta_step=8.15; path_smooth=4.07 : y = 0.914 : 71.7 secs : initdesign
#
# [mbo] 0: num_leaves=823; max_depth=20; min_child_weight=6.49; min_data_in_leaf=7160; min_gain_to_split=0.067; lambda_l1=482; lambda_l2=762; scale_pos_weight=1.52; learning_rate=0.0473; num_iterations=990; early_stopping_rounds=355; feature_fraction=0.295; bagging_fraction=0.857; bagging_freq=2; max_delta_step=7.16; path_smooth=6.9 : y = 0.875 : 46.8 secs : initdesign
#
# [mbo] 0: num_leaves=763; max_depth=20; min_child_weight=4.49; min_data_in_leaf=3434; min_gain_to_split=0.0406; lambda_l1=253; lambda_l2=769; scale_pos_weight=1.37; learning_rate=0.0794; num_iterations=2826; early_stopping_rounds=385; feature_fraction=0.931; bagging_fraction=0.647; bagging_freq=4; max_delta_step=5.15; path_smooth=4.68 : y = 0.874 : 19.1 secs : initdesign
#
# [mbo] 0: num_leaves=5716; max_depth=5; min_child_weight=6.35; min_data_in_leaf=5169; min_gain_to_split=0.0716; lambda_l1=287; lambda_l2=503; scale_pos_weight=3.65; learning_rate=0.0764; num_iterations=4187; early_stopping_rounds=447; feature_fraction=0.802; bagging_fraction=0.886; bagging_freq=3; max_delta_step=4.6; path_smooth=6.04 : y = 0.901 : 32.2 secs : initdesign
#
# [mbo] 0: num_leaves=337; max_depth=29; min_child_weight=3.12; min_data_in_leaf=2826; min_gain_to_split=0.0699; lambda_l1=819; lambda_l2=731; scale_pos_weight=4.2; learning_rate=0.051; num_iterations=2862; early_stopping_rounds=98; feature_fraction=0.513; bagging_fraction=0.841; bagging_freq=3; max_delta_step=3.03; path_smooth=8.31 : y = 0.891 : 37.4 secs : initdesign
#
# [mbo] 0: num_leaves=4157; max_depth=6; min_child_weight=5.33; min_data_in_leaf=3659; min_gain_to_split=0.0722; lambda_l1=645; lambda_l2=590; scale_pos_weight=1.98; learning_rate=0.0528; num_iterations=413; early_stopping_rounds=278; feature_fraction=0.399; bagging_fraction=0.722; bagging_freq=4; max_delta_step=6.94; path_smooth=1.48 : y = 0.882 : 34.8 secs : initdesign
#
# [mbo] 0: num_leaves=3391; max_depth=10; min_child_weight=6.63; min_data_in_leaf=5540; min_gain_to_split=0.0539; lambda_l1=624; lambda_l2=837; scale_pos_weight=3.14; learning_rate=0.078; num_iterations=919; early_stopping_rounds=394; feature_fraction=0.594; bagging_fraction=0.797; bagging_freq=3; max_delta_step=0.275; path_smooth=7.43 : y = 0.888 : 53.5 secs : initdesign
#
# [mbo] 0: num_leaves=3579; max_depth=17; min_child_weight=3.46; min_data_in_leaf=2481; min_gain_to_split=0.0892; lambda_l1=409; lambda_l2=198; scale_pos_weight=3.57; learning_rate=0.0507; num_iterations=3469; early_stopping_rounds=107; feature_fraction=0.182; bagging_fraction=0.929; bagging_freq=4; max_delta_step=4.99; path_smooth=2.6 : y = 0.897 : 25.6 secs : initdesign
#
# [mbo] 0: num_leaves=5537; max_depth=19; min_child_weight=9.32; min_data_in_leaf=2196; min_gain_to_split=0.087; lambda_l1=185; lambda_l2=623; scale_pos_weight=4.28; learning_rate=0.0176; num_iterations=4002; early_stopping_rounds=371; feature_fraction=0.282; bagging_fraction=0.606; bagging_freq=2; max_delta_step=0.654; path_smooth=2.19 : y = 0.91 : 297.2 secs : initdesign
#
# [mbo] 0: num_leaves=1888; max_depth=17; min_child_weight=1.8; min_data_in_leaf=2658; min_gain_to_split=0.027; lambda_l1=147; lambda_l2=574; scale_pos_weight=2.91; learning_rate=0.0221; num_iterations=3328; early_stopping_rounds=223; feature_fraction=0.609; bagging_fraction=0.615; bagging_freq=2; max_delta_step=9.23; path_smooth=6.13 : y = 0.907 : 220.2 secs : initdesign
#
# [mbo] 0: num_leaves=3689; max_depth=22; min_child_weight=1.28; min_data_in_leaf=786; min_gain_to_split=0.00244; lambda_l1=53.2; lambda_l2=203; scale_pos_weight=3.31; learning_rate=0.0414; num_iterations=1115; early_stopping_rounds=364; feature_fraction=0.896; bagging_fraction=0.874; bagging_freq=2; max_delta_step=1.23; path_smooth=3.4 : y = 0.914 : 109.5 secs : initdesign
#
# [mbo] 0: num_leaves=3857; max_depth=5; min_child_weight=4.68; min_data_in_leaf=5080; min_gain_to_split=0.0424; lambda_l1=731; lambda_l2=478; scale_pos_weight=3.88; learning_rate=0.0333; num_iterations=4887; early_stopping_rounds=236; feature_fraction=0.699; bagging_fraction=0.595; bagging_freq=4; max_delta_step=2.46; path_smooth=6.64 : y = 0.885 : 16.6 secs : initdesign
#
# [mbo] 0: num_leaves=7761; max_depth=21; min_child_weight=3.42; min_data_in_leaf=4163; min_gain_to_split=0.0471; lambda_l1=889; lambda_l2=104; scale_pos_weight=4.02; learning_rate=0.0462; num_iterations=755; early_stopping_rounds=288; feature_fraction=0.47; bagging_fraction=0.742; bagging_freq=5; max_delta_step=6.01; path_smooth=5.9 : y = 0.893 : 46.3 secs : initdesign
#
# [mbo] 0: num_leaves=6844; max_depth=13; min_child_weight=4.93; min_data_in_leaf=6822; min_gain_to_split=0.0817; lambda_l1=108; lambda_l2=277; scale_pos_weight=4.33; learning_rate=0.0854; num_iterations=2167; early_stopping_rounds=331; feature_fraction=0.125; bagging_fraction=0.757; bagging_freq=3; max_delta_step=4.48; path_smooth=8.92 : y = 0.914 : 92.6 secs : initdesign
#
# [mbo] 0: num_leaves=3015; max_depth=4; min_child_weight=9.7; min_data_in_leaf=1603; min_gain_to_split=0.0327; lambda_l1=110; lambda_l2=828; scale_pos_weight=4.84; learning_rate=0.0585; num_iterations=4605; early_stopping_rounds=240; feature_fraction=0.778; bagging_fraction=0.877; bagging_freq=1; max_delta_step=1.6; path_smooth=4.95 : y = 0.913 : 65.0 secs : initdesign
#
# [mbo] 0: num_leaves=3301; max_depth=9; min_child_weight=8.79; min_data_in_leaf=3094; min_gain_to_split=0.00437; lambda_l1=908; lambda_l2=711; scale_pos_weight=3.41; learning_rate=0.0648; num_iterations=4258; early_stopping_rounds=442; feature_fraction=0.577; bagging_fraction=0.629; bagging_freq=2; max_delta_step=8.52; path_smooth=2.71 : y = 0.889 : 58.3 secs : initdesign
#
# [mbo] 0: num_leaves=4379; max_depth=28; min_child_weight=5.05; min_data_in_leaf=2080; min_gain_to_split=0.0145; lambda_l1=718; lambda_l2=261; scale_pos_weight=2.87; learning_rate=0.0493; num_iterations=3828; early_stopping_rounds=74; feature_fraction=0.331; bagging_fraction=0.951; bagging_freq=5; max_delta_step=0.925; path_smooth=8.72 : y = 0.891 : 20.5 secs : initdesign
#
# [mbo] 0: num_leaves=5353; max_depth=11; min_child_weight=3.68; min_data_in_leaf=4087; min_gain_to_split=0.0365; lambda_l1=299; lambda_l2=455; scale_pos_weight=4.63; learning_rate=0.0922; num_iterations=2269; early_stopping_rounds=247; feature_fraction=0.957; bagging_fraction=0.538; bagging_freq=3; max_delta_step=8.99; path_smooth=4.69 : y = 0.895 : 12.4 secs : initdesign
#
# [mbo] 0: num_leaves=1740; max_depth=14; min_child_weight=7.16; min_data_in_leaf=6732; min_gain_to_split=0.0343; lambda_l1=358; lambda_l2=369; scale_pos_weight=4.17; learning_rate=0.0323; num_iterations=1785; early_stopping_rounds=123; feature_fraction=0.67; bagging_fraction=0.906; bagging_freq=4; max_delta_step=8.38; path_smooth=7.08 : y = 0.901 : 28.6 secs : initdesign
#
# [mbo] 0: num_leaves=1189; max_depth=24; min_child_weight=5.89; min_data_in_leaf=1746; min_gain_to_split=0.0249; lambda_l1=771; lambda_l2=794; scale_pos_weight=2.04; learning_rate=0.0446; num_iterations=3140; early_stopping_rounds=168; feature_fraction=0.815; bagging_fraction=0.817; bagging_freq=2; max_delta_step=2.31; path_smooth=1.08 : y = 0.879 : 10.2 secs : initdesign
#
# [mbo] 0: num_leaves=6457; max_depth=18; min_child_weight=7.66; min_data_in_leaf=394; min_gain_to_split=0.00559; lambda_l1=534; lambda_l2=922; scale_pos_weight=2.18; learning_rate=0.0312; num_iterations=515; early_stopping_rounds=65; feature_fraction=0.142; bagging_fraction=0.805; bagging_freq=0; max_delta_step=7.69; path_smooth=2.42 : y = 0.892 : 14.5 secs : initdesign
#
# [mbo] 0: num_leaves=2586; max_depth=11; min_child_weight=8.04; min_data_in_leaf=1274; min_gain_to_split=0.0774; lambda_l1=573; lambda_l2=432; scale_pos_weight=2.43; learning_rate=0.0188; num_iterations=697; early_stopping_rounds=133; feature_fraction=0.0732; bagging_fraction=0.558; bagging_freq=3; max_delta_step=6.15; path_smooth=8.1 : y = 0.891 : 28.8 secs : initdesign
#
# [mbo] 0: num_leaves=5093; max_depth=18; min_child_weight=2.75; min_data_in_leaf=320; min_gain_to_split=0.091; lambda_l1=496; lambda_l2=908; scale_pos_weight=4.74; learning_rate=0.0584; num_iterations=3615; early_stopping_rounds=291; feature_fraction=0.954; bagging_fraction=0.935; bagging_freq=5; max_delta_step=4.22; path_smooth=7.24 : y = 0.901 : 27.2 secs : initdesign
#
# [mbo] 0: num_leaves=1101; max_depth=26; min_child_weight=3.27; min_data_in_leaf=5372; min_gain_to_split=0.0216; lambda_l1=986; lambda_l2=156; scale_pos_weight=2.7; learning_rate=0.0104; num_iterations=4063; early_stopping_rounds=473; feature_fraction=0.554; bagging_fraction=0.688; bagging_freq=2; max_delta_step=5.71; path_smooth=7.55 : y = 0.882 : 105.8 secs : initdesign
#
# [mbo] 0: num_leaves=5167; max_depth=27; min_child_weight=3.98; min_data_in_leaf=956; min_gain_to_split=0.0407; lambda_l1=690; lambda_l2=420; scale_pos_weight=2.62; learning_rate=0.0693; num_iterations=1221; early_stopping_rounds=184; feature_fraction=0.758; bagging_fraction=0.728; bagging_freq=0; max_delta_step=9.91; path_smooth=9.89 : y = 0.885 : 14.0 secs : initdesign
#
# [mbo] 0: num_leaves=7225; max_depth=25; min_child_weight=5.74; min_data_in_leaf=6542; min_gain_to_split=0.052; lambda_l1=870; lambda_l2=562; scale_pos_weight=4.56; learning_rate=0.067; num_iterations=4098; early_stopping_rounds=404; feature_fraction=0.435; bagging_fraction=0.707; bagging_freq=0; max_delta_step=0.538; path_smooth=3.77 : y = 0.892 : 62.4 secs : initdesign
#
# [mbo] 0: num_leaves=7636; max_depth=22; min_child_weight=9.66; min_data_in_leaf=7800; min_gain_to_split=0.0563; lambda_l1=451; lambda_l2=865; scale_pos_weight=1.03; learning_rate=0.0275; num_iterations=147; early_stopping_rounds=226; feature_fraction=0.442; bagging_fraction=0.578; bagging_freq=4; max_delta_step=6.57; path_smooth=6.78 : y = 0.855 : 18.8 secs : initdesign
#
# [mbo] 0: num_leaves=2932; max_depth=27; min_child_weight=4.78; min_data_in_leaf=4232; min_gain_to_split=0.0612; lambda_l1=31.8; lambda_l2=438; scale_pos_weight=1.06; learning_rate=0.0616; num_iterations=1254; early_stopping_rounds=149; feature_fraction=0.334; bagging_fraction=0.86; bagging_freq=5; max_delta_step=1.86; path_smooth=5.7 : y = 0.911 : 121.3 secs : initdesign
#
# [mbo] 0: num_leaves=6982; max_depth=16; min_child_weight=1.12; min_data_in_leaf=7321; min_gain_to_split=0.0233; lambda_l1=204; lambda_l2=806; scale_pos_weight=3.97; learning_rate=0.0257; num_iterations=309; early_stopping_rounds=347; feature_fraction=0.412; bagging_fraction=0.894; bagging_freq=2; max_delta_step=3.21; path_smooth=1.16 : y = 0.901 : 41.4 secs : initdesign
#
# [mbo] 0: num_leaves=1293; max_depth=15; min_child_weight=7.41; min_data_in_leaf=1144; min_gain_to_split=0.0763; lambda_l1=679; lambda_l2=88.5; scale_pos_weight=1.81; learning_rate=0.0849; num_iterations=3172; early_stopping_rounds=399; feature_fraction=0.566; bagging_fraction=0.682; bagging_freq=2; max_delta_step=4.82; path_smooth=4.3 : y = 0.878 : 51.9 secs : initdesign
#
# [mbo] 0: num_leaves=3091; max_depth=3; min_child_weight=2.1; min_data_in_leaf=5478; min_gain_to_split=0.0298; lambda_l1=858; lambda_l2=240; scale_pos_weight=4.09; learning_rate=0.0112; num_iterations=3874; early_stopping_rounds=459; feature_fraction=0.989; bagging_fraction=0.991; bagging_freq=0; max_delta_step=0.129; path_smooth=8.83 : y = 0.892 : 187.7 secs : initdesign
#
# [mbo] 0: num_leaves=7450; max_depth=21; min_child_weight=1.41; min_data_in_leaf=1328; min_gain_to_split=0.0924; lambda_l1=734; lambda_l2=220; scale_pos_weight=2.08; learning_rate=0.0206; num_iterations=3257; early_stopping_rounds=315; feature_fraction=0.457; bagging_fraction=0.522; bagging_freq=2; max_delta_step=1.31; path_smooth=2.85 : y = 0.883 : 56.9 secs : initdesign
#
# [mbo] 0: num_leaves=461; max_depth=26; min_child_weight=4.09; min_data_in_leaf=5913; min_gain_to_split=0.000702; lambda_l1=523; lambda_l2=518; scale_pos_weight=4.48; learning_rate=0.094; num_iterations=2341; early_stopping_rounds=62; feature_fraction=0.0645; bagging_fraction=0.963; bagging_freq=0; max_delta_step=5.19; path_smooth=3.95 : y = 0.885 : 28.0 secs : initdesign
#
# [mbo] 0: num_leaves=5445; max_depth=10; min_child_weight=6.78; min_data_in_leaf=7597; min_gain_to_split=0.00681; lambda_l1=584; lambda_l2=154; scale_pos_weight=1.4; learning_rate=0.0385; num_iterations=2565; early_stopping_rounds=176; feature_fraction=0.868; bagging_fraction=0.779; bagging_freq=4; max_delta_step=2.02; path_smooth=3.6 : y = 0.86 : 20.3 secs : initdesign
#
# [mbo] 0: num_leaves=4269; max_depth=8; min_child_weight=9.03; min_data_in_leaf=1810; min_gain_to_split=0.00825; lambda_l1=832; lambda_l2=404; scale_pos_weight=3.56; learning_rate=0.00545; num_iterations=1068; early_stopping_rounds=471; feature_fraction=0.213; bagging_fraction=0.939; bagging_freq=5; max_delta_step=8; path_smooth=0.088 : y = 0.898 : 96.6 secs : initdesign
#
# [mbo] 0: num_leaves=1959; max_depth=6; min_child_weight=0.31; min_data_in_leaf=7451; min_gain_to_split=0.0735; lambda_l1=130; lambda_l2=676; scale_pos_weight=3.49; learning_rate=0.0738; num_iterations=4464; early_stopping_rounds=210; feature_fraction=0.708; bagging_fraction=0.79; bagging_freq=4; max_delta_step=0.963; path_smooth=0.732 : y = 0.911 : 35.4 secs : initdesign
#
# [mbo] 0: num_leaves=7057; max_depth=9; min_child_weight=5.29; min_data_in_leaf=7007; min_gain_to_split=0.0645; lambda_l1=977; lambda_l2=320; scale_pos_weight=1.18; learning_rate=0.0756; num_iterations=619; early_stopping_rounds=260; feature_fraction=0.304; bagging_fraction=0.506; bagging_freq=0; max_delta_step=7.4; path_smooth=3.24 : y = 0.814 : 37.5 secs : initdesign
#
# [mbo] 0: num_leaves=963; max_depth=7; min_child_weight=9.16; min_data_in_leaf=5688; min_gain_to_split=0.0947; lambda_l1=232; lambda_l2=28.6; scale_pos_weight=1.65; learning_rate=0.0374; num_iterations=2081; early_stopping_rounds=99; feature_fraction=0.495; bagging_fraction=0.904; bagging_freq=0; max_delta_step=4.06; path_smooth=2.17 : y = 0.892 : 35.4 secs : initdesign
#
# [mbo] 0: num_leaves=4512; max_depth=4; min_child_weight=8.15; min_data_in_leaf=4892; min_gain_to_split=0.0195; lambda_l1=158; lambda_l2=296; scale_pos_weight=1.72; learning_rate=0.0995; num_iterations=1378; early_stopping_rounds=496; feature_fraction=0.971; bagging_fraction=0.718; bagging_freq=1; max_delta_step=2.92; path_smooth=8.55 : y = 0.902 : 55.2 secs : initdesign
#
# [mbo] 0: num_leaves=7908; max_depth=28; min_child_weight=1.05; min_data_in_leaf=3515; min_gain_to_split=0.035; lambda_l1=328; lambda_l2=951; scale_pos_weight=2.67; learning_rate=0.0423; num_iterations=3717; early_stopping_rounds=141; feature_fraction=0.349; bagging_fraction=0.55; bagging_freq=1; max_delta_step=9.54; path_smooth=1.33 : y = 0.887 : 280.7 secs : initdesign
#
# [mbo] 0: num_leaves=4935; max_depth=22; min_child_weight=0.46; min_data_in_leaf=68; min_gain_to_split=0.0852; lambda_l1=25.7; lambda_l2=653; scale_pos_weight=4.56; learning_rate=0.0141; num_iterations=4712; early_stopping_rounds=489; feature_fraction=0.195; bagging_fraction=0.826; bagging_freq=3; max_delta_step=0.321; path_smooth=5.2 : y = 0.92 : 560.4 secs : initdesign
#
# [mbo] 0: num_leaves=7992; max_depth=23; min_child_weight=5.54; min_data_in_leaf=3815; min_gain_to_split=0.0955; lambda_l1=960; lambda_l2=638; scale_pos_weight=2.31; learning_rate=0.0353; num_iterations=2976; early_stopping_rounds=412; feature_fraction=0.237; bagging_fraction=0.979; bagging_freq=5; max_delta_step=3.44; path_smooth=9.3 : y = 0.889 : 45.1 secs : initdesign
#
# [mbo] 0: num_leaves=588; max_depth=11; min_child_weight=0.014; min_data_in_leaf=6484; min_gain_to_split=0.0626; lambda_l1=596; lambda_l2=699; scale_pos_weight=3.09; learning_rate=0.0949; num_iterations=1940; early_stopping_rounds=80; feature_fraction=0.12; bagging_fraction=0.633; bagging_freq=5; max_delta_step=9.51; path_smooth=4.4 : y = 0.88 : 12.4 secs : initdesign
#
# [mbo] 0: num_leaves=3740; max_depth=8; min_child_weight=9.46; min_data_in_leaf=4354; min_gain_to_split=0.0992; lambda_l1=76.7; lambda_l2=969; scale_pos_weight=1.44; learning_rate=0.0602; num_iterations=4655; early_stopping_rounds=482; feature_fraction=0.646; bagging_fraction=0.789; bagging_freq=3; max_delta_step=5.55; path_smooth=0.229 : y = 0.904 : 58.3 secs : initdesign
#
# [mbo] 0: num_leaves=7413; max_depth=23; min_child_weight=8.57; min_data_in_leaf=8148; min_gain_to_split=0.0802; lambda_l1=200; lambda_l2=358; scale_pos_weight=2.53; learning_rate=0.0402; num_iterations=5000; early_stopping_rounds=139; feature_fraction=0.858; bagging_fraction=0.527; bagging_freq=1; max_delta_step=2.12; path_smooth=7.81 : y = 0.9 : 166.8 secs : initdesign
#
# [mbo] 0: num_leaves=2355; max_depth=30; min_child_weight=2.21; min_data_in_leaf=4600; min_gain_to_split=0.0178; lambda_l1=665; lambda_l2=50; scale_pos_weight=1.3; learning_rate=0.0134; num_iterations=400; early_stopping_rounds=214; feature_fraction=0.206; bagging_fraction=0.762; bagging_freq=0; max_delta_step=9.83; path_smooth=3.06 : y = 0.873 : 36.7 secs : initdesign
#
# [mbo] 0: num_leaves=6175; max_depth=24; min_child_weight=7.28; min_data_in_leaf=5885; min_gain_to_split=0.0458; lambda_l1=395; lambda_l2=980; scale_pos_weight=5; learning_rate=0.0718; num_iterations=1930; early_stopping_rounds=263; feature_fraction=0.902; bagging_fraction=0.997; bagging_freq=1; max_delta_step=9.21; path_smooth=5.54 : y = 0.899 : 31.3 secs : initdesign
#
# [mbo] 0: num_leaves=94; max_depth=18; min_child_weight=0.766; min_data_in_leaf=3255; min_gain_to_split=0.098; lambda_l1=364; lambda_l2=115; scale_pos_weight=4.4; learning_rate=0.0961; num_iterations=1713; early_stopping_rounds=454; feature_fraction=0.255; bagging_fraction=0.565; bagging_freq=0; max_delta_step=7.58; path_smooth=9.58 : y = 0.894 : 55.4 secs : initdesign
#
# [mbo] 0: num_leaves=6330; max_depth=6; min_child_weight=6.93; min_data_in_leaf=6029; min_gain_to_split=0.0283; lambda_l1=946; lambda_l2=992; scale_pos_weight=3.7; learning_rate=0.0711; num_iterations=1574; early_stopping_rounds=334; feature_fraction=0.745; bagging_fraction=0.512; bagging_freq=5; max_delta_step=3.64; path_smooth=0.353 : y = 0.885 : 15.6 secs : initdesign
#
# [mbo] 0: num_leaves=2208; max_depth=16; min_child_weight=1.97; min_data_in_leaf=166; min_gain_to_split=0.011; lambda_l1=335; lambda_l2=749; scale_pos_weight=2.26; learning_rate=0.0159; num_iterations=4513; early_stopping_rounds=88; feature_fraction=0.102; bagging_fraction=0.957; bagging_freq=5; max_delta_step=2.69; path_smooth=0.538 : y = 0.893 : 30.9 secs : initdesign
#
# [mbo] 0: num_leaves=4625; max_depth=30; min_child_weight=7.95; min_data_in_leaf=603; min_gain_to_split=0.0125; lambda_l1=15.3; lambda_l2=886; scale_pos_weight=2.21; learning_rate=0.0881; num_iterations=2708; early_stopping_rounds=306; feature_fraction=0.166; bagging_fraction=0.68; bagging_freq=1; max_delta_step=4.34; path_smooth=7.92 : y = 0.92 : 196.5 secs : initdesign
#
# [mbo] 0: num_leaves=5880; max_depth=8; min_child_weight=0.582; min_data_in_leaf=3910; min_gain_to_split=0.0882; lambda_l1=627; lambda_l2=310; scale_pos_weight=4.81; learning_rate=0.00881; num_iterations=2410; early_stopping_rounds=160; feature_fraction=0.847; bagging_fraction=0.743; bagging_freq=0; max_delta_step=7.28; path_smooth=0.923 : y = 0.9 : 71.8 secs : initdesign
#
# [mbo] 0: num_leaves=8176; max_depth=28; min_child_weight=9.99; min_data_in_leaf=2373; min_gain_to_split=0.0494; lambda_l1=790; lambda_l2=176; scale_pos_weight=3.8; learning_rate=0.0974; num_iterations=4795; early_stopping_rounds=54; feature_fraction=0.537; bagging_fraction=0.67; bagging_freq=4; max_delta_step=6.43; path_smooth=1.67 : y = 0.889 : 15.4 secs : initdesign
#
# [mbo] 0: num_leaves=202; max_depth=5; min_child_weight=3.81; min_data_in_leaf=736; min_gain_to_split=0.0686; lambda_l1=904; lambda_l2=858; scale_pos_weight=1.6; learning_rate=0.0272; num_iterations=193; early_stopping_rounds=345; feature_fraction=0.918; bagging_fraction=0.593; bagging_freq=3; max_delta_step=8.87; path_smooth=9.1 : y = 0.842 : 7.0 secs : initdesign
#
# [mbo] 0: num_leaves=6026; max_depth=3; min_child_weight=4.34; min_data_in_leaf=7938; min_gain_to_split=0.00939; lambda_l1=244; lambda_l2=137; scale_pos_weight=1.22; learning_rate=0.0547; num_iterations=3661; early_stopping_rounds=192; feature_fraction=0.259; bagging_fraction=0.969; bagging_freq=0; max_delta_step=7.84; path_smooth=9.73 : y = 0.882 : 36.8 secs : initdesign
#
# [mbo] 0: num_leaves=1653; max_depth=14; min_child_weight=7.55; min_data_in_leaf=3064; min_gain_to_split=0.0161; lambda_l1=387; lambda_l2=12.6; scale_pos_weight=4.89; learning_rate=0.00703; num_iterations=1463; early_stopping_rounds=374; feature_fraction=0.388; bagging_fraction=0.7; bagging_freq=4; max_delta_step=1.48; path_smooth=8.21 : y = 0.9 : 166.6 secs : initdesign
#
# [mbo] 0: num_leaves=1435; max_depth=29; min_child_weight=0.817; min_data_in_leaf=7838; min_gain_to_split=0.084; lambda_l1=926; lambda_l2=899; scale_pos_weight=1.93; learning_rate=0.0901; num_iterations=4380; early_stopping_rounds=180; feature_fraction=0.674; bagging_fraction=0.917; bagging_freq=1; max_delta_step=3.38; path_smooth=5.15 : y = 0.876 : 9.5 secs : initdesign
#
# Saved the current state after iteration 1 in the file HT.RDATA.
#
# Wed Nov 19 02:15:46 AM 2025 AUC 0.924905497295944
#
# [mbo] 1: num_leaves=3778; max_depth=22; min_child_weight=5.13; min_data_in_leaf=2565; min_gain_to_split=0.0555; lambda_l1=2.35; lambda_l2=272; scale_pos_weight=2.91; learning_rate=0.0394; num_iterations=3388; early_stopping_rounds=339; feature_fraction=0.171; bagging_fraction=0.794; bagging_freq=2; max_delta_step=1.21; path_smooth=6.64 : y = 0.925 : 355.8 secs : infill_ei
#
# Wed Nov 19 02:21:59 AM 2025 AUC 0.920709664474298
#
# [mbo] 2: num_leaves=3836; max_depth=16; min_child_weight=5.01; min_data_in_leaf=3398; min_gain_to_split=0.0695; lambda_l1=0.0912; lambda_l2=777; scale_pos_weight=3.74; learning_rate=0.04; num_iterations=2585; early_stopping_rounds=367; feature_fraction=0.392; bagging_fraction=0.841; bagging_freq=3; max_delta_step=1.36; path_smooth=8.28 : y = 0.921 : 370.9 secs : infill_ei
#
# Saved the current state after iteration 3 in the file HT.RDATA.
#
# Wed Nov 19 02:28:44 AM 2025 AUC 0.923569071695895
#
# [mbo] 3: num_leaves=3934; max_depth=24; min_child_weight=4.7; min_data_in_leaf=4979; min_gain_to_split=0.0542; lambda_l1=0.515; lambda_l2=541; scale_pos_weight=2.61; learning_rate=0.0806; num_iterations=3247; early_stopping_rounds=458; feature_fraction=0.284; bagging_fraction=0.888; bagging_freq=1; max_delta_step=1.39; path_smooth=5.7 : y = 0.924 : 403.3 secs : infill_ei
#
# Wed Nov 19 02:31:28 AM 2025 AUC 0.918684726363251
#
# [mbo] 4: num_leaves=4076; max_depth=24; min_child_weight=2.19; min_data_in_leaf=5657; min_gain_to_split=0.0882; lambda_l1=7.42; lambda_l2=313; scale_pos_weight=4.1; learning_rate=0.07; num_iterations=3927; early_stopping_rounds=318; feature_fraction=0.616; bagging_fraction=0.784; bagging_freq=1; max_delta_step=2.59; path_smooth=7.9 : y = 0.919 : 162.2 secs : infill_ei
#
# Wed Nov 19 02:38:32 AM 2025 AUC 0.922551066355561
#
# [mbo] 5: num_leaves=4163; max_depth=17; min_child_weight=1.16; min_data_in_leaf=1923; min_gain_to_split=0.0778; lambda_l1=4.24; lambda_l2=536; scale_pos_weight=2.57; learning_rate=0.0843; num_iterations=3755; early_stopping_rounds=377; feature_fraction=0.216; bagging_fraction=0.823; bagging_freq=2; max_delta_step=2.45; path_smooth=6.2 : y = 0.923 : 422.4 secs : infill_ei
#
# Saved the current state after iteration 6 in the file HT.RDATA.
#
# Wed Nov 19 02:45:08 AM 2025 AUC 0.924310598328109
#
# [mbo] 6: num_leaves=4210; max_depth=28; min_child_weight=5.65; min_data_in_leaf=800; min_gain_to_split=0.0828; lambda_l1=0.856; lambda_l2=652; scale_pos_weight=2.65; learning_rate=0.0517; num_iterations=2829; early_stopping_rounds=144; feature_fraction=0.341; bagging_fraction=0.816; bagging_freq=1; max_delta_step=2.86; path_smooth=5.45 : y = 0.924 : 394.2 secs : infill_ei
#
# Wed Nov 19 02:49:57 AM 2025 AUC 0.922414504663565
#
# [mbo] 7: num_leaves=3823; max_depth=27; min_child_weight=6.67; min_data_in_leaf=2987; min_gain_to_split=0.0512; lambda_l1=0.497; lambda_l2=580; scale_pos_weight=2.56; learning_rate=0.0591; num_iterations=3578; early_stopping_rounds=228; feature_fraction=0.261; bagging_fraction=0.894; bagging_freq=1; max_delta_step=1.55; path_smooth=8.45 : y = 0.922 : 287.4 secs : infill_ei
#
# Saved the current state after iteration 8 in the file HT.RDATA.
#
# Wed Nov 19 02:53:14 AM 2025 AUC 0.922739971103949
#
# [mbo] 8: num_leaves=4240; max_depth=22; min_child_weight=5.78; min_data_in_leaf=970; min_gain_to_split=0.0805; lambda_l1=0.597; lambda_l2=333; scale_pos_weight=2.37; learning_rate=0.0349; num_iterations=1680; early_stopping_rounds=406; feature_fraction=0.203; bagging_fraction=0.8; bagging_freq=2; max_delta_step=1.19; path_smooth=5.63 : y = 0.923 : 195.5 secs : infill_ei
#
# Wed Nov 19 02:57:06 AM 2025 AUC 0.919826207631483
#
# [mbo] 9: num_leaves=3649; max_depth=25; min_child_weight=1.23; min_data_in_leaf=4504; min_gain_to_split=0.0839; lambda_l1=1.08; lambda_l2=295; scale_pos_weight=2.82; learning_rate=0.0557; num_iterations=2281; early_stopping_rounds=235; feature_fraction=0.162; bagging_fraction=0.821; bagging_freq=3; max_delta_step=4.42; path_smooth=5.77 : y = 0.92 : 229.9 secs : infill_ei
#
# Wed Nov 19 03:06:18 AM 2025 AUC 0.92237625396851
#
# [mbo] 10: num_leaves=4593; max_depth=23; min_child_weight=4.16; min_data_in_leaf=1138; min_gain_to_split=0.0441; lambda_l1=1.14; lambda_l2=546; scale_pos_weight=3.05; learning_rate=0.0418; num_iterations=4329; early_stopping_rounds=209; feature_fraction=0.456; bagging_fraction=0.769; bagging_freq=2; max_delta_step=0.691; path_smooth=4.82 : y = 0.922 : 549.5 secs : infill_ei
#
# Saved the current state after iteration 11 in the file HT.RDATA.
#
# Wed Nov 19 03:13:07 AM 2025 AUC 0.921250207191265
#
# [mbo] 11: num_leaves=2800; max_depth=27; min_child_weight=5.61; min_data_in_leaf=60; min_gain_to_split=0.0732; lambda_l1=14.9; lambda_l2=551; scale_pos_weight=3.34; learning_rate=0.0283; num_iterations=3717; early_stopping_rounds=243; feature_fraction=0.179; bagging_fraction=0.708; bagging_freq=1; max_delta_step=4.07; path_smooth=6.91 : y = 0.921 : 407.2 secs : infill_ei
#
# Wed Nov 19 03:18:23 AM 2025 AUC 0.922287337879126
#
# [mbo] 12: num_leaves=3384; max_depth=14; min_child_weight=7.45; min_data_in_leaf=2781; min_gain_to_split=0.0896; lambda_l1=0.699; lambda_l2=168; scale_pos_weight=2.87; learning_rate=0.057; num_iterations=2880; early_stopping_rounds=254; feature_fraction=0.518; bagging_fraction=0.783; bagging_freq=1; max_delta_step=1.01; path_smooth=5.62 : y = 0.922 : 313.7 secs : infill_ei
#
# Saved the current state after iteration 13 in the file HT.RDATA.
#
# Wed Nov 19 03:28:49 AM 2025 AUC 0.925057493478928
#
# [mbo] 13: num_leaves=4766; max_depth=22; min_child_weight=5.31; min_data_in_leaf=690; min_gain_to_split=0.0754; lambda_l1=3.25; lambda_l2=312; scale_pos_weight=2.84; learning_rate=0.041; num_iterations=4152; early_stopping_rounds=445; feature_fraction=0.458; bagging_fraction=0.783; bagging_freq=1; max_delta_step=4.25; path_smooth=8.2 : y = 0.925 : 625.0 secs : infill_ei
#
# Saved the current state after iteration 14 in the file HT.RDATA.
#
# Wed Nov 19 03:32:25 AM 2025 AUC 0.92603892578627
#
# [mbo] 14: num_leaves=4364; max_depth=22; min_child_weight=4.44; min_data_in_leaf=150; min_gain_to_split=0.0626; lambda_l1=0.727; lambda_l2=299; scale_pos_weight=2.83; learning_rate=0.087; num_iterations=1315; early_stopping_rounds=172; feature_fraction=0.372; bagging_fraction=0.789; bagging_freq=1; max_delta_step=2.2; path_smooth=9.29 : y = 0.926 : 213.8 secs : infill_ei
#
# Wed Nov 19 03:41:28 AM 2025 AUC 0.924414613376067
#
# [mbo] 15: num_leaves=4724; max_depth=15; min_child_weight=5.06; min_data_in_leaf=859; min_gain_to_split=0.0711; lambda_l1=7.83; lambda_l2=276; scale_pos_weight=4.35; learning_rate=0.0448; num_iterations=3986; early_stopping_rounds=389; feature_fraction=0.306; bagging_fraction=0.844; bagging_freq=2; max_delta_step=2.3; path_smooth=7.62 : y = 0.924 : 540.4 secs : infill_ei
#
# Saved the current state after iteration 16 in the file HT.RDATA.
#
# Wed Nov 19 03:45:46 AM 2025 AUC 0.927142491891859
#
# [mbo] 16: num_leaves=5451; max_depth=13; min_child_weight=2.94; min_data_in_leaf=437; min_gain_to_split=0.0479; lambda_l1=7.53; lambda_l2=140; scale_pos_weight=3.25; learning_rate=0.0417; num_iterations=3239; early_stopping_rounds=466; feature_fraction=0.234; bagging_fraction=0.752; bagging_freq=0; max_delta_step=1.17; path_smooth=6.71 : y = 0.927 : 255.7 secs : infill_ei
#
# Wed Nov 19 03:50:34 AM 2025 AUC 0.927848116555907
#
# [mbo] 17: num_leaves=5149; max_depth=28; min_child_weight=3.42; min_data_in_leaf=1045; min_gain_to_split=0.0244; lambda_l1=0.29; lambda_l2=436; scale_pos_weight=3.09; learning_rate=0.0653; num_iterations=2397; early_stopping_rounds=495; feature_fraction=0.201; bagging_fraction=0.777; bagging_freq=1; max_delta_step=1.06; path_smooth=8.86 : y = 0.928 : 285.7 secs : infill_ei
#
# Wed Nov 19 03:53:51 AM 2025 AUC 0.925147416165549
#
# [mbo] 18: num_leaves=4775; max_depth=20; min_child_weight=2.6; min_data_in_leaf=2870; min_gain_to_split=0.0583; lambda_l1=0.362; lambda_l2=307; scale_pos_weight=2.97; learning_rate=0.0612; num_iterations=2246; early_stopping_rounds=414; feature_fraction=0.0921; bagging_fraction=0.673; bagging_freq=0; max_delta_step=0.336; path_smooth=9.32 : y = 0.925 : 195.4 secs : infill_ei
#
# Saved the current state after iteration 19 in the file HT.RDATA.
#
# Wed Nov 19 03:58:26 AM 2025 AUC 0.926664358203667
#
# [mbo] 19: num_leaves=6326; max_depth=18; min_child_weight=7.08; min_data_in_leaf=227; min_gain_to_split=0.0513; lambda_l1=5.81; lambda_l2=355; scale_pos_weight=3.33; learning_rate=0.0723; num_iterations=2231; early_stopping_rounds=440; feature_fraction=0.196; bagging_fraction=0.835; bagging_freq=1; max_delta_step=1.92; path_smooth=7.95 : y = 0.927 : 273.0 secs : infill_ei
#
# Wed Nov 19 04:03:37 AM 2025 AUC 0.924197859437419
#
# [mbo] 20: num_leaves=6375; max_depth=11; min_child_weight=4.29; min_data_in_leaf=366; min_gain_to_split=0.0301; lambda_l1=0.904; lambda_l2=389; scale_pos_weight=3; learning_rate=0.0796; num_iterations=3200; early_stopping_rounds=416; feature_fraction=0.313; bagging_fraction=0.636; bagging_freq=1; max_delta_step=1.52; path_smooth=8.46 : y = 0.924 : 309.3 secs : infill_ei
#
# Wed Nov 19 04:07:17 AM 2025 AUC 0.923353995419312
#
# [mbo] 21: num_leaves=4187; max_depth=26; min_child_weight=3.99; min_data_in_leaf=2000; min_gain_to_split=0.0728; lambda_l1=3.42; lambda_l2=232; scale_pos_weight=3.05; learning_rate=0.0874; num_iterations=3113; early_stopping_rounds=480; feature_fraction=0.411; bagging_fraction=0.844; bagging_freq=0; max_delta_step=0.694; path_smooth=9.18 : y = 0.923 : 216.6 secs : infill_ei
#
# Saved the current state after iteration 22 in the file HT.RDATA.
#
# Wed Nov 19 04:11:34 AM 2025 AUC 0.925903370691512
#
# [mbo] 22: num_leaves=2561; max_depth=15; min_child_weight=3.57; min_data_in_leaf=396; min_gain_to_split=0.0189; lambda_l1=4.41; lambda_l2=310; scale_pos_weight=2.97; learning_rate=0.0656; num_iterations=2411; early_stopping_rounds=465; feature_fraction=0.126; bagging_fraction=0.823; bagging_freq=1; max_delta_step=2.31; path_smooth=8.61 : y = 0.926 : 255.8 secs : infill_ei
#
# Wed Nov 19 04:16:03 AM 2025 AUC 0.926869032975454
#
# [mbo] 23: num_leaves=5788; max_depth=22; min_child_weight=3.03; min_data_in_leaf=1026; min_gain_to_split=0.0244; lambda_l1=0.452; lambda_l2=64.6; scale_pos_weight=3.21; learning_rate=0.0724; num_iterations=2194; early_stopping_rounds=395; feature_fraction=0.273; bagging_fraction=0.782; bagging_freq=1; max_delta_step=2.23; path_smooth=7.93 : y = 0.927 : 266.7 secs : infill_ei
#
# Wed Nov 19 04:23:48 AM 2025 AUC 0.926051676017955
#
# [mbo] 24: num_leaves=4752; max_depth=14; min_child_weight=4.35; min_data_in_leaf=325; min_gain_to_split=0.0407; lambda_l1=0.348; lambda_l2=375; scale_pos_weight=3.22; learning_rate=0.0352; num_iterations=2495; early_stopping_rounds=465; feature_fraction=0.487; bagging_fraction=0.773; bagging_freq=1; max_delta_step=2.54; path_smooth=8.77 : y = 0.926 : 463.1 secs : infill_ei
#
# Saved the current state after iteration 25 in the file HT.RDATA.
#
# Wed Nov 19 04:28:58 AM 2025 AUC 0.921264635085014
#
# [mbo] 25: num_leaves=6276; max_depth=22; min_child_weight=2.88; min_data_in_leaf=1623; min_gain_to_split=0.062; lambda_l1=5.37; lambda_l2=615; scale_pos_weight=4.18; learning_rate=0.0424; num_iterations=2828; early_stopping_rounds=462; feature_fraction=0.168; bagging_fraction=0.833; bagging_freq=1; max_delta_step=1.23; path_smooth=7.67 : y = 0.921 : 307.6 secs : infill_ei
#
# Wed Nov 19 04:33:00 AM 2025 AUC 0.921895771553428
#
# [mbo] 26: num_leaves=4888; max_depth=20; min_child_weight=2.97; min_data_in_leaf=92; min_gain_to_split=0.0552; lambda_l1=20.8; lambda_l2=250; scale_pos_weight=2.99; learning_rate=0.0581; num_iterations=2876; early_stopping_rounds=464; feature_fraction=0.197; bagging_fraction=0.726; bagging_freq=1; max_delta_step=1.93; path_smooth=8.08 : y = 0.922 : 240.0 secs : infill_ei
#
# Wed Nov 19 04:34:28 AM 2025 AUC 0.919390686559712
#
# [mbo] 27: num_leaves=6230; max_depth=27; min_child_weight=4.7; min_data_in_leaf=1793; min_gain_to_split=0.03; lambda_l1=0.521; lambda_l2=348; scale_pos_weight=2.83; learning_rate=0.0558; num_iterations=558; early_stopping_rounds=339; feature_fraction=0.365; bagging_fraction=0.869; bagging_freq=0; max_delta_step=3.01; path_smooth=8.81 : y = 0.919 : 84.8 secs : infill_ei
#
# Saved the current state after iteration 28 in the file HT.RDATA.
#
# Wed Nov 19 04:39:12 AM 2025 AUC 0.924711224028952
#
# [mbo] 28: num_leaves=3758; max_depth=20; min_child_weight=7.94; min_data_in_leaf=4478; min_gain_to_split=0.00952; lambda_l1=0.398; lambda_l2=258; scale_pos_weight=3.29; learning_rate=0.065; num_iterations=3809; early_stopping_rounds=498; feature_fraction=0.378; bagging_fraction=0.754; bagging_freq=0; max_delta_step=4.04; path_smooth=7.48 : y = 0.925 : 281.7 secs : infill_ei
#
# Wed Nov 19 04:46:34 AM 2025 AUC 0.927504195832822
#
# [mbo] 29: num_leaves=5610; max_depth=6; min_child_weight=8.43; min_data_in_leaf=2037; min_gain_to_split=0.044; lambda_l1=0.129; lambda_l2=121; scale_pos_weight=3.6; learning_rate=0.0243; num_iterations=3737; early_stopping_rounds=467; feature_fraction=0.271; bagging_fraction=0.801; bagging_freq=0; max_delta_step=3.89; path_smooth=7.72 : y = 0.928 : 440.3 secs : infill_ei
#
# Saved the current state after iteration 30 in the file HT.RDATA.
#
# Wed Nov 19 04:54:25 AM 2025 AUC 0.929243931393017
#
# [mbo] 30: num_leaves=5965; max_depth=13; min_child_weight=8.13; min_data_in_leaf=908; min_gain_to_split=0.0707; lambda_l1=1.74; lambda_l2=117; scale_pos_weight=4.25; learning_rate=0.0156; num_iterations=4964; early_stopping_rounds=487; feature_fraction=0.713; bagging_fraction=0.783; bagging_freq=0; max_delta_step=5.9; path_smooth=2.42 : y = 0.929 : 468.6 secs : infill_ei
#
# Wed Nov 19 05:03:46 AM 2025 AUC 0.925572200200112
#
# [mbo] 31: num_leaves=4674; max_depth=7; min_child_weight=6.13; min_data_in_leaf=833; min_gain_to_split=0.0908; lambda_l1=2.26; lambda_l2=229; scale_pos_weight=3.57; learning_rate=0.0134; num_iterations=3921; early_stopping_rounds=278; feature_fraction=0.345; bagging_fraction=0.886; bagging_freq=0; max_delta_step=3.01; path_smooth=2.2 : y = 0.926 : 559.7 secs : infill_ei
#
# Saved the current state after iteration 32 in the file HT.RDATA.
#
# Wed Nov 19 05:12:36 AM 2025 AUC 0.927605526621477
#
# [mbo] 32: num_leaves=5996; max_depth=14; min_child_weight=7.47; min_data_in_leaf=1277; min_gain_to_split=0.0253; lambda_l1=1.84; lambda_l2=319; scale_pos_weight=3.37; learning_rate=0.0267; num_iterations=4419; early_stopping_rounds=436; feature_fraction=0.188; bagging_fraction=0.787; bagging_freq=0; max_delta_step=2.71; path_smooth=6.2 : y = 0.928 : 527.5 secs : infill_ei
#
# Wed Nov 19 05:18:11 AM 2025 AUC 0.929192930466276
#
# [mbo] 33: num_leaves=5774; max_depth=5; min_child_weight=4.3; min_data_in_leaf=2282; min_gain_to_split=0.0419; lambda_l1=0.128; lambda_l2=239; scale_pos_weight=3.47; learning_rate=0.0724; num_iterations=2848; early_stopping_rounds=483; feature_fraction=0.281; bagging_fraction=0.806; bagging_freq=0; max_delta_step=0.37; path_smooth=2.03 : y = 0.929 : 332.7 secs : infill_ei
#
# Saved the current state after iteration 34 in the file HT.RDATA.
#
# Wed Nov 19 05:32:04 AM 2025 AUC 0.924805173104527
#
# [mbo] 34: num_leaves=5409; max_depth=8; min_child_weight=5.11; min_data_in_leaf=3976; min_gain_to_split=0.0653; lambda_l1=0.11; lambda_l2=50.7; scale_pos_weight=4.19; learning_rate=0.0106; num_iterations=4707; early_stopping_rounds=423; feature_fraction=0.55; bagging_fraction=0.876; bagging_freq=1; max_delta_step=5.12; path_smooth=2.54 : y = 0.925 : 830.1 secs : infill_ei
#
# Saved the current state after iteration 35 in the file HT.RDATA.
#
# Wed Nov 19 05:34:39 AM 2025 AUC 0.927984678247903
#
# [mbo] 35: num_leaves=5418; max_depth=7; min_child_weight=5.92; min_data_in_leaf=1907; min_gain_to_split=0.0109; lambda_l1=0.993; lambda_l2=84.4; scale_pos_weight=3.74; learning_rate=0.0952; num_iterations=2533; early_stopping_rounds=239; feature_fraction=0.0837; bagging_fraction=0.909; bagging_freq=1; max_delta_step=1.07; path_smooth=8.41 : y = 0.928 : 153.3 secs : infill_ei
#
# Wed Nov 19 05:38:25 AM 2025 AUC 0.931723851455775
#
# [mbo] 36: num_leaves=5513; max_depth=24; min_child_weight=7.76; min_data_in_leaf=358; min_gain_to_split=0.0212; lambda_l1=0.232; lambda_l2=16.5; scale_pos_weight=3.97; learning_rate=0.0295; num_iterations=4524; early_stopping_rounds=441; feature_fraction=0.674; bagging_fraction=0.815; bagging_freq=1; max_delta_step=6.61; path_smooth=5.57 : y = 0.932 : 224.3 secs : infill_ei
#
# Wed Nov 19 05:44:05 AM 2025 AUC 0.932214399843239
#
# [mbo] 37: num_leaves=3689; max_depth=6; min_child_weight=5.25; min_data_in_leaf=272; min_gain_to_split=0.0578; lambda_l1=0.795; lambda_l2=0.514; scale_pos_weight=4.07; learning_rate=0.0194; num_iterations=3697; early_stopping_rounds=487; feature_fraction=0.738; bagging_fraction=0.811; bagging_freq=0; max_delta_step=2.27; path_smooth=4.05 : y = 0.932 : 336.5 secs : infill_ei
#
# Saved the current state after iteration 38 in the file HT.RDATA.
#
# Wed Nov 19 05:47:19 AM 2025 AUC 0.926822058437667
#
# [mbo] 38: num_leaves=6282; max_depth=9; min_child_weight=5.88; min_data_in_leaf=2327; min_gain_to_split=0.0384; lambda_l1=0.127; lambda_l2=18.6; scale_pos_weight=3.73; learning_rate=0.0416; num_iterations=4226; early_stopping_rounds=483; feature_fraction=0.939; bagging_fraction=0.844; bagging_freq=1; max_delta_step=0.491; path_smooth=3.41 : y = 0.927 : 192.2 secs : infill_ei
#
# Wed Nov 19 05:51:48 AM 2025 AUC 0.929353314959578
#
# [mbo] 39: num_leaves=4987; max_depth=9; min_child_weight=1.12; min_data_in_leaf=76; min_gain_to_split=0.0323; lambda_l1=0.294; lambda_l2=193; scale_pos_weight=4.02; learning_rate=0.072; num_iterations=4266; early_stopping_rounds=324; feature_fraction=0.778; bagging_fraction=0.785; bagging_freq=0; max_delta_step=8.88; path_smooth=7.05 : y = 0.929 : 266.3 secs : infill_ei
#
# Wed Nov 19 05:57:58 AM 2025 AUC 0.926623423249309
#
# [mbo] 40: num_leaves=4189; max_depth=11; min_child_weight=5; min_data_in_leaf=873; min_gain_to_split=0.0195; lambda_l1=0.363; lambda_l2=250; scale_pos_weight=4.19; learning_rate=0.0182; num_iterations=4232; early_stopping_rounds=112; feature_fraction=0.665; bagging_fraction=0.646; bagging_freq=0; max_delta_step=8.02; path_smooth=6.92 : y = 0.927 : 367.1 secs : infill_ei
#
# Saved the current state after iteration 41 in the file HT.RDATA.
#
# Wed Nov 19 06:01:04 AM 2025 AUC 0.925530929713341
#
# [mbo] 41: num_leaves=3871; max_depth=4; min_child_weight=4.79; min_data_in_leaf=485; min_gain_to_split=0.0257; lambda_l1=0.94; lambda_l2=66.3; scale_pos_weight=4.01; learning_rate=0.0662; num_iterations=3959; early_stopping_rounds=449; feature_fraction=0.759; bagging_fraction=0.869; bagging_freq=1; max_delta_step=8.58; path_smooth=7.06 : y = 0.926 : 183.4 secs : infill_ei
#
# Wed Nov 19 06:09:08 AM 2025 AUC 0.929350295167863
#
# [mbo] 42: num_leaves=4555; max_depth=17; min_child_weight=6.01; min_data_in_leaf=26; min_gain_to_split=0.0431; lambda_l1=0.312; lambda_l2=50.2; scale_pos_weight=4.34; learning_rate=0.0173; num_iterations=3209; early_stopping_rounds=377; feature_fraction=0.841; bagging_fraction=0.709; bagging_freq=0; max_delta_step=3.56; path_smooth=6.87 : y = 0.929 : 481.8 secs : infill_ei
#
# Saved the current state after iteration 43 in the file HT.RDATA.
#
# Wed Nov 19 06:16:57 AM 2025 AUC 0.928692316106428
#
# [mbo] 43: num_leaves=4090; max_depth=9; min_child_weight=6.38; min_data_in_leaf=318; min_gain_to_split=0.0165; lambda_l1=1.25; lambda_l2=136; scale_pos_weight=4.04; learning_rate=0.0163; num_iterations=3187; early_stopping_rounds=366; feature_fraction=0.621; bagging_fraction=0.802; bagging_freq=0; max_delta_step=1.07; path_smooth=5.97 : y = 0.929 : 466.6 secs : infill_ei
#
# Wed Nov 19 06:25:47 AM 2025 AUC 0.925802375435269
#
# [mbo] 44: num_leaves=4936; max_depth=10; min_child_weight=2.39; min_data_in_leaf=673; min_gain_to_split=0.0144; lambda_l1=2.82; lambda_l2=99.2; scale_pos_weight=4.19; learning_rate=0.019; num_iterations=4838; early_stopping_rounds=473; feature_fraction=0.729; bagging_fraction=0.773; bagging_freq=3; max_delta_step=5.14; path_smooth=3.22 : y = 0.926 : 528.3 secs : infill_ei
#
# Saved the current state after iteration 45 in the file HT.RDATA.
#
# Wed Nov 19 06:30:28 AM 2025 AUC 0.926598258318352
#
# [mbo] 45: num_leaves=4149; max_depth=11; min_child_weight=2.38; min_data_in_leaf=594; min_gain_to_split=0.0708; lambda_l1=0.038; lambda_l2=97.3; scale_pos_weight=4.21; learning_rate=0.0213; num_iterations=3658; early_stopping_rounds=418; feature_fraction=0.675; bagging_fraction=0.815; bagging_freq=0; max_delta_step=7.3; path_smooth=3.69 : y = 0.927 : 277.5 secs : infill_ei
#
# Wed Nov 19 06:33:11 AM 2025 AUC 0.930372326897151
#
# ...
#
# Wed Nov 19 09:10:15 AM 2025 AUC 0.929977740779737
#
# [mbo] 86: num_leaves=3597; max_depth=24; min_child_weight=7.77; min_data_in_leaf=10; min_gain_to_split=0.00195; lambda_l1=0.57; lambda_l2=1.35; scale_pos_weight=4.02; learning_rate=0.0243; num_iterations=4075; early_stopping_rounds=229; feature_fraction=0.0728; bagging_fraction=0.552; bagging_freq=2; max_delta_step=8.09; path_smooth=7.23 : y = 0.93 : 139.1 secs : infill_ei
#
# Saved the current state after iteration 87 in the file HT.RDATA.
#
# Wed Nov 19 09:12:23 AM 2025 AUC 0.931203776215986
#
# [mbo] 87: num_leaves=6186; max_depth=12; min_child_weight=6.83; min_data_in_leaf=512; min_gain_to_split=0.0301; lambda_l1=0.867; lambda_l2=3.39; scale_pos_weight=4.07; learning_rate=0.0608; num_iterations=2239; early_stopping_rounds=344; feature_fraction=0.0988; bagging_fraction=0.993; bagging_freq=5; max_delta_step=1.36; path_smooth=2.5 : y = 0.931 : 123.5 secs : infill_ei
#
# Wed Nov 19 09:16:45 AM 2025 AUC 0.931892288726983
#
# [mbo] 88: num_leaves=3552; max_depth=27; min_child_weight=5.7; min_data_in_leaf=359; min_gain_to_split=0.0219; lambda_l1=0.676; lambda_l2=9.26; scale_pos_weight=3.54; learning_rate=0.0315; num_iterations=1781; early_stopping_rounds=362; feature_fraction=0.26; bagging_fraction=0.711; bagging_freq=5; max_delta_step=7.85; path_smooth=6.9 : y = 0.932 : 259.5 secs : infill_ei
#
# Wed Nov 19 09:19:12 AM 2025 AUC 0.925138021257991
#
# [mbo] 89: num_leaves=7789; max_depth=5; min_child_weight=8.06; min_data_in_leaf=922; min_gain_to_split=0.0771; lambda_l1=1.51; lambda_l2=65.8; scale_pos_weight=3.96; learning_rate=0.0598; num_iterations=4338; early_stopping_rounds=262; feature_fraction=0.0607; bagging_fraction=0.983; bagging_freq=3; max_delta_step=4.3; path_smooth=2.01 : y = 0.925 : 143.5 secs : infill_ei
#
# Wed Nov 19 09:25:43 AM 2025 AUC 0.927791747110563
#
# [mbo] 90: num_leaves=4657; max_depth=30; min_child_weight=7.43; min_data_in_leaf=331; min_gain_to_split=0.00665; lambda_l1=0.11; lambda_l2=194; scale_pos_weight=4.17; learning_rate=0.0624; num_iterations=2394; early_stopping_rounds=466; feature_fraction=0.538; bagging_fraction=0.959; bagging_freq=5; max_delta_step=6.17; path_smooth=6.26 : y = 0.928 : 386.3 secs : infill_ei
#
# Saved the current state after iteration 91 in the file HT.RDATA.
#
# Wed Nov 19 09:27:28 AM 2025 AUC 0.929191923869038
#
# [mbo] 91: num_leaves=8155; max_depth=14; min_child_weight=9.17; min_data_in_leaf=837; min_gain_to_split=0.0171; lambda_l1=2.82; lambda_l2=25.9; scale_pos_weight=4.21; learning_rate=0.0397; num_iterations=2395; early_stopping_rounds=139; feature_fraction=0.18; bagging_fraction=0.856; bagging_freq=0; max_delta_step=1.36; path_smooth=1.19 : y = 0.929 : 100.4 secs : infill_ei
#
# Wed Nov 19 09:28:56 AM 2025 AUC 0.915817601896161
#
# [mbo] 92: num_leaves=8147; max_depth=4; min_child_weight=0.915; min_data_in_leaf=176; min_gain_to_split=0.0783; lambda_l1=0.118; lambda_l2=677; scale_pos_weight=4.55; learning_rate=0.0707; num_iterations=4698; early_stopping_rounds=92; feature_fraction=0.517; bagging_fraction=0.766; bagging_freq=0; max_delta_step=3.98; path_smooth=8.9 : y = 0.916 : 85.1 secs : infill_ei
#
# Wed Nov 19 09:31:11 AM 2025 AUC 0.932203327273618
#
# [mbo] 93: num_leaves=5316; max_depth=26; min_child_weight=7.37; min_data_in_leaf=206; min_gain_to_split=0.00615; lambda_l1=0.184; lambda_l2=2.94; scale_pos_weight=4.7; learning_rate=0.0309; num_iterations=2123; early_stopping_rounds=336; feature_fraction=0.0909; bagging_fraction=0.814; bagging_freq=2; max_delta_step=3.87; path_smooth=3.03 : y = 0.932 : 129.5 secs : infill_ei
#
# Wed Nov 19 09:33:16 AM 2025 AUC 0.927798122226405
#
# [mbo] 94: num_leaves=8139; max_depth=6; min_child_weight=2.14; min_data_in_leaf=1054; min_gain_to_split=0.0104; lambda_l1=0.788; lambda_l2=4.57; scale_pos_weight=4.24; learning_rate=0.0227; num_iterations=4609; early_stopping_rounds=166; feature_fraction=0.191; bagging_fraction=0.814; bagging_freq=5; max_delta_step=2.09; path_smooth=2.51 : y = 0.928 : 122.1 secs : infill_ei
#
# Wed Nov 19 09:39:50 AM 2025 AUC 0.918528032726489
#
# [mbo] 95: num_leaves=3959; max_depth=4; min_child_weight=0.0177; min_data_in_leaf=7529; min_gain_to_split=0.0739; lambda_l1=0.311; lambda_l2=919; scale_pos_weight=3.19; learning_rate=0.0604; num_iterations=3779; early_stopping_rounds=493; feature_fraction=0.227; bagging_fraction=0.678; bagging_freq=0; max_delta_step=1.43; path_smooth=7.67 : y = 0.919 : 391.5 secs : infill_ei
#
# Saved the current state after iteration 96 in the file HT.RDATA.
#
# Wed Nov 19 09:41:38 AM 2025 AUC 0.930540093103534
#
# [mbo] 96: num_leaves=7520; max_depth=14; min_child_weight=5.79; min_data_in_leaf=298; min_gain_to_split=0.00856; lambda_l1=0.4; lambda_l2=2.88; scale_pos_weight=4.06; learning_rate=0.0405; num_iterations=3779; early_stopping_rounds=189; feature_fraction=0.161; bagging_fraction=0.838; bagging_freq=3; max_delta_step=4.93; path_smooth=5.89 : y = 0.931 : 102.5 secs : infill_ei
#
# Wed Nov 19 09:43:26 AM 2025 AUC 0.932950893489262
#
# [mbo] 97: num_leaves=5342; max_depth=25; min_child_weight=7.78; min_data_in_leaf=168; min_gain_to_split=0.016; lambda_l1=1.11; lambda_l2=40.8; scale_pos_weight=3.81; learning_rate=0.0479; num_iterations=2301; early_stopping_rounds=126; feature_fraction=0.187; bagging_fraction=0.92; bagging_freq=5; max_delta_step=2.28; path_smooth=2.64 : y = 0.933 : 104.3 secs : infill_ei
#
# Wed Nov 19 09:46:17 AM 2025 AUC 0.930612903637104
#
# [mbo] 98: num_leaves=4997; max_depth=12; min_child_weight=6.11; min_data_in_leaf=303; min_gain_to_split=0.0297; lambda_l1=2.8; lambda_l2=5.4; scale_pos_weight=4.43; learning_rate=0.0235; num_iterations=3725; early_stopping_rounds=318; feature_fraction=0.0508; bagging_fraction=0.968; bagging_freq=1; max_delta_step=2.72; path_smooth=2.76 : y = 0.931 : 167.9 secs : infill_ei
#
# Wed Nov 19 09:48:54 AM 2025 AUC 0.925781572425678
#
# [mbo] 99: num_leaves=4761; max_depth=6; min_child_weight=7.72; min_data_in_leaf=5424; min_gain_to_split=0.059; lambda_l1=0.947; lambda_l2=8.77; scale_pos_weight=4.59; learning_rate=0.081; num_iterations=4676; early_stopping_rounds=303; feature_fraction=0.813; bagging_fraction=0.609; bagging_freq=0; max_delta_step=9.03; path_smooth=3.6 : y = 0.926 : 153.2 secs : infill_ei
#
# Wed Nov 19 09:51:56 AM 2025 AUC 0.933311926365399
#
# [mbo] 100: num_leaves=5617; max_depth=9; min_child_weight=1.24; min_data_in_leaf=1591; min_gain_to_split=0.0171; lambda_l1=0.213; lambda_l2=10.1; scale_pos_weight=3.47; learning_rate=0.07; num_iterations=2111; early_stopping_rounds=268; feature_fraction=0.314; bagging_fraction=0.947; bagging_freq=5; max_delta_step=4.25; path_smooth=9.8 : y = 0.933 : 178.7 secs : infill_ei
#
# Saved the current state after iteration 101 in the file HT.RDATA.
#
# Wed Nov 19 09:57:51 AM 2025 AUC 0.927379377775272
#
# [mbo] 101: num_leaves=4761; max_depth=30; min_child_weight=8.68; min_data_in_leaf=60; min_gain_to_split=0.0015; lambda_l1=0.197; lambda_l2=420; scale_pos_weight=4.4; learning_rate=0.019; num_iterations=2590; early_stopping_rounds=468; feature_fraction=0.208; bagging_fraction=0.757; bagging_freq=0; max_delta_step=9.65; path_smooth=9.72 : y = 0.927 : 350.5 secs : infill_ei
#
# Wed Nov 19 10:00:56 AM 2025 AUC 0.929895199806197
#
# [mbo] 102: num_leaves=3684; max_depth=26; min_child_weight=8.68; min_data_in_leaf=170; min_gain_to_split=0.0209; lambda_l1=0.0839; lambda_l2=49.1; scale_pos_weight=3.65; learning_rate=0.0559; num_iterations=4126; early_stopping_rounds=327; feature_fraction=0.787; bagging_fraction=0.515; bagging_freq=0; max_delta_step=9.35; path_smooth=9.41 : y = 0.93 : 182.4 secs : infill_ei
#
# Wed Nov 19 10:05:21 AM 2025 AUC 0.928552734622717
#
# [mbo] 103: num_leaves=4159; max_depth=24; min_child_weight=6.01; min_data_in_leaf=7; min_gain_to_split=0.0164; lambda_l1=13.1; lambda_l2=65.6; scale_pos_weight=4.13; learning_rate=0.028; num_iterations=4202; early_stopping_rounds=322; feature_fraction=0.311; bagging_fraction=0.99; bagging_freq=5; max_delta_step=5.17; path_smooth=7.84 : y = 0.929 : 260.3 secs : infill_ei
#
# Saved the current state after iteration 104 in the file HT.RDATA.
#
# Wed Nov 19 10:07:09 AM 2025 AUC 0.929260708013655
#
# [mbo] 104: num_leaves=8009; max_depth=9; min_child_weight=2.35; min_data_in_leaf=1108; min_gain_to_split=0.0214; lambda_l1=0.185; lambda_l2=55.4; scale_pos_weight=3.31; learning_rate=0.0512; num_iterations=1867; early_stopping_rounds=99; feature_fraction=0.0554; bagging_fraction=0.914; bagging_freq=5; max_delta_step=0.731; path_smooth=4.87 : y = 0.929 : 102.8 secs : infill_ei
#
# Wed Nov 19 10:10:01 AM 2025 AUC 0.929323117042429
#
# [mbo] 105: num_leaves=4539; max_depth=26; min_child_weight=7.37; min_data_in_leaf=433; min_gain_to_split=0.0119; lambda_l1=0.0537; lambda_l2=121; scale_pos_weight=4.21; learning_rate=0.0794; num_iterations=2869; early_stopping_rounds=286; feature_fraction=0.327; bagging_fraction=0.602; bagging_freq=0; max_delta_step=7.01; path_smooth=9.21 : y = 0.929 : 167.7 secs : infill_ei
#
# Wed Nov 19 10:13:38 AM 2025 AUC 0.92336473245652
#
# [mbo] 106: num_leaves=4466; max_depth=5; min_child_weight=6.16; min_data_in_leaf=7503; min_gain_to_split=0.0291; lambda_l1=0.125; lambda_l2=223; scale_pos_weight=4.35; learning_rate=0.0958; num_iterations=2026; early_stopping_rounds=421; feature_fraction=0.22; bagging_fraction=0.648; bagging_freq=0; max_delta_step=0.49; path_smooth=0.636 : y = 0.923 : 212.4 secs : infill_ei
#
# Wed Nov 19 10:16:10 AM 2025 AUC 0.925441678091545
#
# [mbo] 107: num_leaves=3352; max_depth=7; min_child_weight=0.442; min_data_in_leaf=3148; min_gain_to_split=0.0613; lambda_l1=0.115; lambda_l2=9.38; scale_pos_weight=3.61; learning_rate=0.0807; num_iterations=2579; early_stopping_rounds=200; feature_fraction=0.288; bagging_fraction=0.802; bagging_freq=5; max_delta_step=7.76; path_smooth=9.34 : y = 0.925 : 147.6 secs : infill_ei
#
# Saved the current state after iteration 108 in the file HT.RDATA.
#
# Wed Nov 19 10:18:45 AM 2025 AUC 0.928824180344645
#
# [mbo] 108: num_leaves=8108; max_depth=5; min_child_weight=1.32; min_data_in_leaf=372; min_gain_to_split=0.0724; lambda_l1=0.126; lambda_l2=22.3; scale_pos_weight=4.22; learning_rate=0.0902; num_iterations=3551; early_stopping_rounds=312; feature_fraction=0.161; bagging_fraction=0.956; bagging_freq=5; max_delta_step=0.832; path_smooth=3.69 : y = 0.929 : 151.7 secs : infill_ei
#
# Wed Nov 19 10:24:07 AM 2025 AUC 0.918535078907157
#
# [mbo] 109: num_leaves=5970; max_depth=19; min_child_weight=7.16; min_data_in_leaf=4943; min_gain_to_split=0.0775; lambda_l1=1.22; lambda_l2=678; scale_pos_weight=2.8; learning_rate=0.094; num_iterations=4614; early_stopping_rounds=472; feature_fraction=0.987; bagging_fraction=0.782; bagging_freq=0; max_delta_step=9.84; path_smooth=9.14 : y = 0.919 : 317.6 secs : infill_ei
#
# Wed Nov 19 10:25:57 AM 2025 AUC 0.922315187069386
#
# [mbo] 110: num_leaves=4945; max_depth=4; min_child_weight=5.82; min_data_in_leaf=4457; min_gain_to_split=0.0526; lambda_l1=0.191; lambda_l2=93.8; scale_pos_weight=4.06; learning_rate=0.0724; num_iterations=3900; early_stopping_rounds=108; feature_fraction=0.784; bagging_fraction=0.682; bagging_freq=0; max_delta_step=0.485; path_smooth=1.8 : y = 0.922 : 105.8 secs : infill_ei
#
# Wed Nov 19 10:33:39 AM 2025 AUC 0.922719168094357
#
# [mbo] 111: num_leaves=7978; max_depth=22; min_child_weight=0.536; min_data_in_leaf=5596; min_gain_to_split=0.00857; lambda_l1=0.313; lambda_l2=30.2; scale_pos_weight=4.71; learning_rate=0.0786; num_iterations=2662; early_stopping_rounds=455; feature_fraction=0.558; bagging_fraction=0.873; bagging_freq=4; max_delta_step=0.761; path_smooth=4.03 : y = 0.923 : 457.9 secs : infill_ei
#
# Saved the current state after iteration 112 in the file HT.RDATA.
#
# Wed Nov 19 10:35:40 AM 2025 AUC 0.92304698326163
#
# [mbo] 112: num_leaves=4096; max_depth=30; min_child_weight=6.83; min_data_in_leaf=187; min_gain_to_split=0.0566; lambda_l1=0.492; lambda_l2=37.1; scale_pos_weight=2.95; learning_rate=0.0402; num_iterations=2212; early_stopping_rounds=96; feature_fraction=0.403; bagging_fraction=0.587; bagging_freq=5; max_delta_step=5.75; path_smooth=9.85 : y = 0.923 : 116.4 secs : infill_ei
#
# Wed Nov 19 10:40:29 AM 2025 AUC 0.924736724492323
#
# [mbo] 113: num_leaves=7721; max_depth=6; min_child_weight=4.28; min_data_in_leaf=7125; min_gain_to_split=0.0694; lambda_l1=0.296; lambda_l2=24.8; scale_pos_weight=3.51; learning_rate=0.0884; num_iterations=4674; early_stopping_rounds=358; feature_fraction=0.601; bagging_fraction=0.837; bagging_freq=0; max_delta_step=0.399; path_smooth=9.85 : y = 0.925 : 284.4 secs : infill_ei
#
# Wed Nov 19 10:48:09 AM 2025 AUC 0.91248106758361
#
# [mbo] 114: num_leaves=8140; max_depth=9; min_child_weight=4.5; min_data_in_leaf=7780; min_gain_to_split=0.0618; lambda_l1=0.00279; lambda_l2=4; scale_pos_weight=4.83; learning_rate=0.0139; num_iterations=3467; early_stopping_rounds=309; feature_fraction=0.365; bagging_fraction=0.884; bagging_freq=4; max_delta_step=0.12; path_smooth=0.795 : y = 0.912 : 454.0 secs : infill_ei
#
# Saved the current state after iteration 115 in the file HT.RDATA.
#
# Wed Nov 19 10:51:26 AM 2025 AUC 0.927956829057644
#
# [mbo] 115: num_leaves=5341; max_depth=28; min_child_weight=1.25; min_data_in_leaf=2316; min_gain_to_split=0.00173; lambda_l1=0.18; lambda_l2=220; scale_pos_weight=3.59; learning_rate=0.0739; num_iterations=2045; early_stopping_rounds=319; feature_fraction=0.0948; bagging_fraction=0.935; bagging_freq=5; max_delta_step=8.7; path_smooth=7.63 : y = 0.928 : 192.2 secs : infill_ei
#
# Wed Nov 19 10:54:04 AM 2025 AUC 0.927059279853493
#
# [mbo] 116: num_leaves=4932; max_depth=26; min_child_weight=0.506; min_data_in_leaf=1059; min_gain_to_split=0.0155; lambda_l1=1.47; lambda_l2=351; scale_pos_weight=4.53; learning_rate=0.0697; num_iterations=1616; early_stopping_rounds=293; feature_fraction=0.0961; bagging_fraction=0.798; bagging_freq=5; max_delta_step=3.95; path_smooth=9.57 : y = 0.927 : 153.6 secs : infill_ei
#
# Wed Nov 19 11:01:43 AM 2025 AUC 0.925416177628175
#
# [mbo] 117: num_leaves=3482; max_depth=6; min_child_weight=2.77; min_data_in_leaf=577; min_gain_to_split=0.0211; lambda_l1=1.13; lambda_l2=187; scale_pos_weight=3.39; learning_rate=0.0117; num_iterations=4961; early_stopping_rounds=291; feature_fraction=0.118; bagging_fraction=0.675; bagging_freq=0; max_delta_step=9.9; path_smooth=9.17 : y = 0.925 : 453.3 secs : infill_ei
#
# Saved the current state after iteration 118 in the file HT.RDATA.
#
# Wed Nov 19 11:07:54 AM 2025 AUC 0.930895757461066
#
# [mbo] 118: num_leaves=6871; max_depth=25; min_child_weight=0.699; min_data_in_leaf=35; min_gain_to_split=0.0674; lambda_l1=0.123; lambda_l2=67.8; scale_pos_weight=3.55; learning_rate=0.0424; num_iterations=2196; early_stopping_rounds=261; feature_fraction=0.446; bagging_fraction=0.994; bagging_freq=5; max_delta_step=3.77; path_smooth=4.34 : y = 0.931 : 366.1 secs : infill_ei
#
# Wed Nov 19 11:10:58 AM 2025 AUC 0.926686167810497
#
# [mbo] 119: num_leaves=8145; max_depth=22; min_child_weight=9.91; min_data_in_leaf=1447; min_gain_to_split=0.0536; lambda_l1=0.564; lambda_l2=235; scale_pos_weight=4.35; learning_rate=0.0831; num_iterations=4288; early_stopping_rounds=257; feature_fraction=0.796; bagging_fraction=0.797; bagging_freq=0; max_delta_step=7.61; path_smooth=4.6 : y = 0.927 : 179.7 secs : infill_ei
#
# Wed Nov 19 11:21:29 AM 2025 AUC 0.925926857960406
#
# [mbo] 120: num_leaves=1170; max_depth=30; min_child_weight=9.88; min_data_in_leaf=127; min_gain_to_split=0.0365; lambda_l1=2.87; lambda_l2=80.5; scale_pos_weight=4.67; learning_rate=0.00661; num_iterations=4594; early_stopping_rounds=457; feature_fraction=0.763; bagging_fraction=0.626; bagging_freq=3; max_delta_step=7.39; path_smooth=9.82 : y = 0.926 : 627.6 secs : infill_ei
#
# Saved the final state in the file HT.RDATA
#
# Saved the final state in the file HT.RDATA

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves max_depth min_child_weight min_data_in_leaf min_gain_to_split
#         <int>     <int>            <num>            <int>             <num>
# 1:       4684        24         7.079116               74       0.002559228
#    lambda_l1 lambda_l2 scale_pos_weight learning_rate num_iterations
#        <num>     <num>            <num>         <num>          <int>
# 1: 0.1688499  1.496051         3.545779     0.0473248           1372
#    early_stopping_rounds feature_fraction bagging_fraction bagging_freq
#                    <int>            <num>            <num>        <int>
# 1:                    79        0.1748965        0.7913094            5
#    max_delta_step path_smooth
#             <num>       <num>
# 1:       5.188234    6.949314

# %% [markdown]
# ### 6.3.3 Produccion

# %% [markdown]
# #### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# ##### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c(
  202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 207504

# %% [markdown]
# ##### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# Para el entrenamiento final, removemos early_stopping_rounds
# ya que se entrena con todos los datos disponibles y la cantidad de iteraciones
# ya está optimizada en 'num_iterations'.
param_final$early_stopping_rounds <- NULL

# %% [markdown]
# ##### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# #### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202107)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# ##### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# #### Curva de Ganancia

# %% [markdown]
# Genero las salidas

# %%
# asigno clase ternaria
tb_prediccion[, clase_ternaria := dfuture$clase_ternaria ]

# asigno ganancias
tb_prediccion[, ganancia := -3000.0 ]
tb_prediccion[clase_ternaria=="BAJA+2", ganancia := 117000.0 ]

# reordeno, y acumulada
setorder( tb_prediccion, -prob )
tb_prediccion[, gan_acum := cumsum(ganancia)]

# media movil de ancho 400
tb_prediccion[,
  gan_suavizada := frollmean(
    x= gan_acum,
    n= 400,
    align= "center",
    na.rm= TRUE,
    hasNA= TRUE
  )
]

# %%
tb_prediccion[, sum(!is.na(gan_suavizada) )]
tb_prediccion[, .N]
# Out:
# [1] 16152
# [1] 16551

# %%
# Este es la ganancia a reportar
resultado <- list()
resultado$ganancia_suavizada_max <- max( tb_prediccion$gan_suavizada, na.rm=TRUE )
options(digits= 8)
resultado$envios <- which.max( tb_prediccion$gan_suavizada)
resultado
# Out:
# $ganancia_suavizada_max
# [1] 6025200
#
# $envios
# [1] 1253

# %%
# grabo las ganancias
fwrite( tb_prediccion,
  file= "ganancias.txt",
  sep= "\t"
)

# %%
# genero el grafico

tb_prediccion[, envios:= .I]

pdf("curva_de_ganancia.pdf")

plot(
  x= tb_prediccion$envios,
  y= tb_prediccion$gan_acum,
  type= "l",
  col= "gray",
  xlim= c(0, 6000),
  ylim= c(0, 8000000),
  main= paste0("Mejor gan prom= ", as.integer(resultado$ganancia_suavizada_max), " envios= ", resultado$envios),
  xlab= "Envios",
  ylab= "Ganancia",
  panel.first= grid()
)

dev.off()
# Out:
# agg_record_88384812
#                   2

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

PARAM$resultado <- resultado

write_yaml( PARAM, file="PARAM.yml")
# Out:
# Loading required package: yaml

# %%
format(Sys.time(), "%a %b %d %X %Y")
fin <- Sys.time()

# Duración en segundos
secs <- as.numeric(difftime(fin, principio, units = "secs"))
secs <- round(secs)

# A hh:mm:ss
h <- secs %/% 3600
m <- (secs %% 3600) %/% 60
s <- secs %% 60
dur_hms <- sprintf("%02d:%02d:%02d", h, m, s)

cat(
  "Inicio: ", format(principio, "%a %b %d %X %Y"), "\n",
  "Fin:    ", format(fin,       "%a %b %d %X %Y"), "\n",
  "Duración (hh:mm:ss): ", dur_hms, "\n",
  sep = ""
)
# Out:
# [1] "Wed Nov 19 11:25:08 AM 2025"
# Inicio: Wed Nov 19 12:43:14 AM 2025
# Fin:    Wed Nov 19 11:25:08 AM 2025
# Duración (hh:mm:ss): 10:41:54
